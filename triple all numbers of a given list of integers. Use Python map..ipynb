# %% [raw]
# Enter list element manually

# %%
import functools

# %%
n = int(input("length of your list: "))
L = []
for i in range(n):
    r = int(input("input integer element %s: "%(i+1)))
    L.append(r)
print(L)
list(map(lambda x: 3*x ,L))
